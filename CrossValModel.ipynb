# %% [markdown]
# ## **Interpretable Classification Algorithm (Cross Val - Accuracy Build)**

# %% [markdown]
# #### **Import Libraries**

# %%
import numpy as np
import pandas as pd
from pandas.api.types import is_numeric_dtype

import sklearn
from sklearn import preprocessing
from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score
from sklearn import metrics

from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier

# %%
class Node:
    def __init__(self):
        self.data = None
        self.left = None
        self.right = None
        
    def addValue(self,data):
        self.data = data
        
    def addLeft(self,leftNode):
        self.left = leftNode
        
    def addRight(self,rightNode):
        self.right = rightNode

# %%
df = pd.read_csv("wineqt.csv")
le = preprocessing.LabelEncoder()
for col_name in df.columns: 
    if(is_numeric_dtype(df[col_name]) is False):
        df[col_name] = le.fit_transform(df[col_name])
        
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  class
# 0      9.4      5
# 1      9.8      5
# 2      9.8      5
# 3      9.8      6
# 4      9.4      5

# %%
kf = KFold(n_splits=10, shuffle=True, random_state=4)
data = np.array(df)
x = data[:,:-1]
y = data[:,-1]

# %% [markdown]
# #### **Phase One - Complete Learning Set**

# %%
def phaseOne():
    
    for train_index, test_index in kf.split(x):
        x_train, x_test, y_train, y_test = x[train_index], x[test_index], y[train_index], y[test_index]
        
        P1RootNode = Node()
        P1RootNode.addValue(x_train)

        DTclf = DecisionTreeClassifier()
        DTaccuracy = (cross_val_score(DTclf, P1RootNode.data, y_train, cv=kf, scoring='accuracy')).mean()

        NBclf = GaussianNB()
        NBaccuracy = (cross_val_score(NBclf, P1RootNode.data, y_train, cv=kf, scoring='accuracy')).mean()

        KNNclf = KNeighborsClassifier(n_neighbors=3)
        KNNaccuracy = (cross_val_score(KNNclf, P1RootNode.data, y_train, cv=kf, scoring='accuracy')).mean()

        #Find model with the best accuracy
        accScoreDict = dict(Decision_Tree=DTaccuracy, Naive_Bayes=NBaccuracy, K_Nearest_Neighbour=KNNaccuracy)
        BestSingleModel = max(accScoreDict, key=accScoreDict.get)
        BestSingleModelValue = max(accScoreDict.values())

    return BestSingleModel, BestSingleModelValue

# %% [markdown]
# #### **Phase Two - Left Branch Split**

# %%
def phaseTwoLeft(col, th, P2RootNode):
    lesserThan = df.loc[df[col] < th]
    lesserThan = np.array(lesserThan)
    x = lesserThan[:,:-1]
    y = lesserThan[:,-1]
    
    accScoreDict = dict(Decision_Tree=0, Naive_Bayes=0, K_Nearest_Neighbour=0)
    
    if len(lesserThan) > 20:
        for train_index, test_index in kf.split(x):
            x_train, x_test, y_train, y_test = x[train_index], x[test_index], y[train_index], y[test_index]
            
            P2LNode = Node()
            P2LNode.addValue(x_train)
            P2RootNode.addLeft(P2LNode)

            DTclf = DecisionTreeClassifier()
            DTaccuracy = (cross_val_score(DTclf, P2RootNode.left.data, y_train, cv=kf, scoring='accuracy')).mean()

            NBclf = GaussianNB()
            NBaccuracy = (cross_val_score(NBclf, P2RootNode.left.data, y_train, cv=kf, scoring='accuracy')).mean()

            try:
                KNNclf = KNeighborsClassifier(n_neighbors=3)
                KNNaccuracy = (cross_val_score(KNNclf, P2RootNode.left.data, y_train, cv=kf, scoring='accuracy')).mean()
            except Exception as e:
                KNNaccuracy = 0

            if DTaccuracy > accScoreDict.get("Decision_Tree"):
                accScoreDict["Decision_Tree"] = DTaccuracy
            if NBaccuracy > accScoreDict.get("Naive_Bayes"):
                accScoreDict["Naive_Bayes"] = NBaccuracy
            if KNNaccuracy > accScoreDict.get("K_Nearest_Neighbour"):
                accScoreDict["K_Nearest_Neighbour"] = KNNaccuracy
    
    BestSingleModel = max(accScoreDict, key=accScoreDict.get)
    BestSingleModelValue = max(accScoreDict.values())
    
    LPercent = len(lesserThan)/len(data)
    
    return BestSingleModel, BestSingleModelValue, LPercent

# %% [markdown]
# #### **Phase Two - Right Branch Split**

# %%
def phaseTwoRight(col, th, P2RootNode):
    greaterThan = df.loc[df[col] >= th]
    greaterThan = np.array(greaterThan)
    x = greaterThan[:,:-1]
    y = greaterThan[:,-1]
    
    accScoreDict = dict(Decision_Tree=0, Naive_Bayes=0, K_Nearest_Neighbour=0)
    
    if len(greaterThan) > 20:
        for train_index, test_index in kf.split(x):
            x_train, x_test, y_train, y_test = x[train_index], x[test_index], y[train_index], y[test_index]
            
            P2RNode = Node()
            P2RNode.addValue(x_train)
            P2RootNode.addRight(P2RNode)
            
            DTclf = DecisionTreeClassifier()
            DTaccuracy = (cross_val_score(DTclf, P2RootNode.right.data, y_train, cv=kf, scoring='accuracy')).mean()
            
            NBclf = GaussianNB()
            NBaccuracy = (cross_val_score(NBclf, P2RootNode.right.data, y_train, cv=kf, scoring='accuracy')).mean()
            
            try:
                KNNclf = KNeighborsClassifier(n_neighbors=3)
                KNNaccuracy = (cross_val_score(KNNclf, P2RootNode.right.data, y_train, cv=kf, scoring='accuracy')).mean()
            except Exception as e:
                KNNaccuracy = 0
                
            if DTaccuracy > accScoreDict.get("Decision_Tree"):
                accScoreDict["Decision_Tree"] = DTaccuracy
            if NBaccuracy > accScoreDict.get("Naive_Bayes"):
                accScoreDict["Naive_Bayes"] = NBaccuracy
            if KNNaccuracy > accScoreDict.get("K_Nearest_Neighbour"):
                accScoreDict["K_Nearest_Neighbour"] = KNNaccuracy
                
    BestSingleModel = max(accScoreDict, key=accScoreDict.get)
    BestSingleModelValue = max(accScoreDict.values())
    
    RPercent = len(greaterThan)/len(data)
    
    return BestSingleModel, BestSingleModelValue, RPercent

# %% [markdown]
# #### **Phase One Vs Two Results**

# %%
bestModelDict = dict()
for col in df.drop(columns="class").columns:
    minValue = df[col].min()
    maxValue = df[col].max()
    
    P2RootNode = Node()
    P2RootNode.addValue(col)
    
    for th in np.arange(minValue, maxValue):
        if phaseTwoLeft(col, th, P2RootNode)[1] != 0 and phaseTwoRight(col, th, P2RootNode)[1] != 0:
            print(f"{col} < {th}: {phaseTwoLeft(col, th, P2RootNode)[0]}, {round(phaseTwoLeft(col, th, P2RootNode)[1],3)}")
            print(f"{col} >= {th}: {phaseTwoRight(col, th, P2RootNode)[0]}, {round(phaseTwoRight(col, th, P2RootNode)[1],3)}")
            
        leftBranch = phaseTwoLeft(col, th, P2RootNode)[0], phaseTwoLeft(col, th, P2RootNode)[1]
        rightBranch = phaseTwoRight(col, th, P2RootNode)[0], phaseTwoRight(col, th, P2RootNode)[1]
        LRWeight = phaseTwoLeft(col, th, P2RootNode)[2], phaseTwoRight(col, th, P2RootNode)[2]
        modelPair = phaseTwoLeft(col, th, P2RootNode)[0] + " & " + phaseTwoRight(col, th, P2RootNode)[0]
        value = (phaseTwoLeft(col, th, P2RootNode)[1]*phaseTwoLeft(col, th, P2RootNode)[2]) + (phaseTwoRight(col, th, P2RootNode)[1]*phaseTwoRight(col, th, P2RootNode)[2])
        modelValueList = [modelPair, value, leftBranch, rightBranch, col, th, LRWeight]
        bestModelDict[col+str(th)] = modelValueList
    print("\n")
    
bestList = []
for key in bestModelDict:
    if len(bestList) != 0:
        if bestModelDict[key][1] > bestList[1][1]:
            bestList.clear()
            bestList.append(key)
            bestList.append(bestModelDict[key])
    else:
        bestList.append(key)
        bestList.append(bestModelDict[key])
        
print(f"Model (Left): {bestList[1][4]} {bestList[1][5]}, {bestList[1][2][0]}, {round(bestList[1][2][1],3)}, {bestList[1][6][0]}")
print(f"Model (Right): {bestList[1][4]} {bestList[1][5]}, {bestList[1][3][0]}, {round(bestList[1][3][1],3)}, {bestList[1][6][1]}")

Phase1BestModel = phaseOne()
print(f"Model (Phase 1): {Phase1BestModel[0]}, {round(Phase1BestModel[1],3)}\n")

if bestList[1][1] > Phase1BestModel[1]:
    print(f"Best Model (Phase 2): {bestList[1][4]} {bestList[1][5]}, {bestList[1][0]}, {round(bestList[1][1],3)}")
else:
    print(f"Best Model (Phase 1): {Phase1BestModel}")
# Out:
# fixed acidity < 5.6: K_Nearest_Neighbour, 0.65
# fixed acidity >= 5.6: Decision_Tree, 0.597
# fixed acidity < 6.6: Naive_Bayes, 0.577
# fixed acidity >= 6.6: Decision_Tree, 0.611
# fixed acidity < 7.6: Decision_Tree, 0.603
# fixed acidity >= 7.6: Decision_Tree, 0.585
# fixed acidity < 8.6: Decision_Tree, 0.611
# fixed acidity >= 8.6: Decision_Tree, 0.61
# fixed acidity < 9.6: Decision_Tree, 0.609
# fixed acidity >= 9.6: Decision_Tree, 0.532
# fixed acidity < 10.6: Decision_Tree, 0.608
# fixed acidity >= 10.6: Decision_Tree, 0.643
# fixed acidity < 11.6: Decision_Tree, 0.614
# fixed acidity >= 11.6: Decision_Tree, 0.679
# fixed acidity < 12.6: Decision_Tree, 0.608
# fixed acidity >= 12.6: Decision_Tree, 0.633
#
#
#
#
#
#
# residual sugar < 1.9: Decision_Tree, 0.601
# residual sugar >= 1.9: Decision_Tree, 0.602
# residual sugar < 2.9: Decision_Tree, 0.61
# residual sugar >= 2.9: Decision_Tree, 0.609
# residual sugar < 3.8999999999999995: Decision_Tree, 0.615
# residual sugar >= 3.8999999999999995: Decision_Tree, 0.581
# residual sugar < 4.8999999999999995: Decision_Tree, 0.598
# residual sugar >= 4.8999999999999995: Decision_Tree, 0.643
# residual sugar < 5.8999999999999995: Decision_Tree, 0.594
# residual sugar >= 5.8999999999999995: Naive_Bayes, 0.633
#
#
#
#
# free sulfur dioxide < 4.0: Decision_Tree, 0.7
# free sulfur dioxide >= 4.0: Decision_Tree, 0.608
# free sulfur dioxide < 5.0: Decision_Tree, 0.65
# free sulfur dioxide >= 5.0: Decision_Tree, 0.596
# free sulfur dioxide < 6.0: Decision_Tree, 0.569
# free sulfur dioxide >= 6.0: Decision_Tree, 0.614
# free sulfur dioxide < 7.0: Decision_Tree, 0.544
# free sulfur dioxide >= 7.0: Decision_Tree, 0.609
# free sulfur dioxide < 8.0: Decision_Tree, 0.596
# free sulfur dioxide >= 8.0: Decision_Tree, 0.635
# free sulfur dioxide < 9.0: Decision_Tree, 0.59
# free sulfur dioxide >= 9.0: Decision_Tree, 0.625
# free sulfur dioxide < 10.0: Decision_Tree, 0.567
# free sulfur dioxide >= 10.0: Decision_Tree, 0.628
# free sulfur dioxide < 11.0: Decision_Tree, 0.578
# free sulfur dioxide >= 11.0: Decision_Tree, 0.659
# free sulfur dioxide < 12.0: Decision_Tree, 0.587
# free sulfur dioxide >= 12.0: Decision_Tree, 0.644
# free sulfur dioxide < 13.0: Decision_Tree, 0.561
# free sulfur dioxide >= 13.0: Decision_Tree, 0.649
# free sulfur dioxide < 14.0: Decision_Tree, 0.562
# free sulfur dioxide >= 14.0: Decision_Tree, 0.665
# free sulfur dioxide < 15.0: Decision_Tree, 0.547
# free sulfur dioxide >= 15.0: Naive_Bayes, 0.648
# free sulfur dioxide < 16.0: Decision_Tree, 0.547
# free sulfur dioxide >= 16.0: Naive_Bayes, 0.648
# free sulfur dioxide < 17.0: Decision_Tree, 0.559
# free sulfur dioxide >= 17.0: Naive_Bayes, 0.644
# free sulfur dioxide < 18.0: Decision_Tree, 0.56
# free sulfur dioxide >= 18.0: Decision_Tree, 0.631
# free sulfur dioxide < 19.0: Decision_Tree, 0.597
# free sulfur dioxide >= 19.0: Decision_Tree, 0.64
# free sulfur dioxide < 20.0: Decision_Tree, 0.585
# free sulfur dioxide >= 20.0: Naive_Bayes, 0.653
# free sulfur dioxide < 21.0: Decision_Tree, 0.589
# free sulfur dioxide >= 21.0: Decision_Tree, 0.681
# free sulfur dioxide < 22.0: Decision_Tree, 0.596
# free sulfur dioxide >= 22.0: Decision_Tree, 0.656
# free sulfur dioxide < 23.0: Decision_Tree, 0.589
# free sulfur dioxide >= 23.0: Naive_Bayes, 0.688
# free sulfur dioxide < 24.0: Decision_Tree, 0.574
# free sulfur dioxide >= 24.0: Decision_Tree, 0.693
# free sulfur dioxide < 25.0: Decision_Tree, 0.586
# free sulfur dioxide >= 25.0: Naive_Bayes, 0.702
# free sulfur dioxide < 26.0: Decision_Tree, 0.582
# free sulfur dioxide >= 26.0: Naive_Bayes, 0.693
# free sulfur dioxide < 27.0: Decision_Tree, 0.596
# free sulfur dioxide >= 27.0: Naive_Bayes, 0.71
# free sulfur dioxide < 28.0: Decision_Tree, 0.583
# free sulfur dioxide >= 28.0: Naive_Bayes, 0.734
# free sulfur dioxide < 29.0: Decision_Tree, 0.598
# free sulfur dioxide >= 29.0: Naive_Bayes, 0.746
# free sulfur dioxide < 30.0: Decision_Tree, 0.613
# free sulfur dioxide >= 30.0: Naive_Bayes, 0.742
# free sulfur dioxide < 31.0: Decision_Tree, 0.607
# free sulfur dioxide >= 31.0: Naive_Bayes, 0.751
# free sulfur dioxide < 32.0: Decision_Tree, 0.606
# free sulfur dioxide >= 32.0: Decision_Tree, 0.708
# free sulfur dioxide < 33.0: Decision_Tree, 0.578
# free sulfur dioxide >= 33.0: Naive_Bayes, 0.755
# free sulfur dioxide < 34.0: Decision_Tree, 0.589
# free sulfur dioxide >= 34.0: Decision_Tree, 0.771
# free sulfur dioxide < 35.0: Decision_Tree, 0.595
# free sulfur dioxide >= 35.0: Decision_Tree, 0.743
# free sulfur dioxide < 36.0: Decision_Tree, 0.591
# free sulfur dioxide >= 36.0: Decision_Tree, 0.745
# free sulfur dioxide < 37.0: Decision_Tree, 0.587
# free sulfur dioxide >= 37.0: Decision_Tree, 0.808
# free sulfur dioxide < 38.0: Decision_Tree, 0.595
# free sulfur dioxide >= 38.0: Naive_Bayes, 0.792
# free sulfur dioxide < 39.0: Decision_Tree, 0.597
# free sulfur dioxide >= 39.0: Naive_Bayes, 0.817
# free sulfur dioxide < 40.0: Decision_Tree, 0.585
# free sulfur dioxide >= 40.0: Decision_Tree, 0.733
# free sulfur dioxide < 41.0: Decision_Tree, 0.596
# free sulfur dioxide >= 41.0: Naive_Bayes, 0.817
# free sulfur dioxide < 42.0: Decision_Tree, 0.591
# free sulfur dioxide >= 42.0: Naive_Bayes, 0.7
#
#
# total sulfur dioxide < 10.0: Decision_Tree, 0.667
# total sulfur dioxide >= 10.0: Decision_Tree, 0.595
# total sulfur dioxide < 11.0: Decision_Tree, 0.633
# total sulfur dioxide >= 11.0: Decision_Tree, 0.598
# total sulfur dioxide < 12.0: Decision_Tree, 0.52
# total sulfur dioxide >= 12.0: Decision_Tree, 0.619
# total sulfur dioxide < 13.0: Decision_Tree, 0.586
# total sulfur dioxide >= 13.0: Decision_Tree, 0.603
# total sulfur dioxide < 14.0: Decision_Tree, 0.519
# total sulfur dioxide >= 14.0: Decision_Tree, 0.609
# total sulfur dioxide < 15.0: Decision_Tree, 0.604
# total sulfur dioxide >= 15.0: Decision_Tree, 0.623
# total sulfur dioxide < 16.0: Decision_Tree, 0.59
# total sulfur dioxide >= 16.0: Decision_Tree, 0.625
# total sulfur dioxide < 17.0: Decision_Tree, 0.597
# total sulfur dioxide >= 17.0: Decision_Tree, 0.625
# total sulfur dioxide < 18.0: Decision_Tree, 0.579
# total sulfur dioxide >= 18.0: Decision_Tree, 0.627
# total sulfur dioxide < 19.0: Decision_Tree, 0.515
# total sulfur dioxide >= 19.0: Decision_Tree, 0.615
# total sulfur dioxide < 20.0: Decision_Tree, 0.536
# total sulfur dioxide >= 20.0: Decision_Tree, 0.616
# total sulfur dioxide < 21.0: Decision_Tree, 0.562
# total sulfur dioxide >= 21.0: Decision_Tree, 0.609
# total sulfur dioxide < 22.0: Decision_Tree, 0.595
# total sulfur dioxide >= 22.0: Decision_Tree, 0.609
# total sulfur dioxide < 23.0: Decision_Tree, 0.561
# total sulfur dioxide >= 23.0: Decision_Tree, 0.623
# total sulfur dioxide < 24.0: Decision_Tree, 0.567
# total sulfur dioxide >= 24.0: Decision_Tree, 0.607
# total sulfur dioxide < 25.0: Decision_Tree, 0.55
# total sulfur dioxide >= 25.0: Decision_Tree, 0.627
# total sulfur dioxide < 26.0: Decision_Tree, 0.577
# total sulfur dioxide >= 26.0: Decision_Tree, 0.625
# total sulfur dioxide < 27.0: Decision_Tree, 0.567
# total sulfur dioxide >= 27.0: Decision_Tree, 0.637
# total sulfur dioxide < 28.0: Decision_Tree, 0.622
# total sulfur dioxide >= 28.0: Decision_Tree, 0.634
# total sulfur dioxide < 29.0: Decision_Tree, 0.608
# total sulfur dioxide >= 29.0: Decision_Tree, 0.628
# total sulfur dioxide < 30.0: Decision_Tree, 0.579
# total sulfur dioxide >= 30.0: Decision_Tree, 0.642
# total sulfur dioxide < 31.0: Decision_Tree, 0.575
# total sulfur dioxide >= 31.0: Decision_Tree, 0.628
# total sulfur dioxide < 32.0: Decision_Tree, 0.567
# total sulfur dioxide >= 32.0: Decision_Tree, 0.645
# total sulfur dioxide < 33.0: Decision_Tree, 0.576
# total sulfur dioxide >= 33.0: Decision_Tree, 0.628
# total sulfur dioxide < 34.0: Decision_Tree, 0.604
# total sulfur dioxide >= 34.0: Decision_Tree, 0.641
# total sulfur dioxide < 35.0: Decision_Tree, 0.586
# total sulfur dioxide >= 35.0: Decision_Tree, 0.651
# total sulfur dioxide < 36.0: Decision_Tree, 0.577
# total sulfur dioxide >= 36.0: Decision_Tree, 0.637
# total sulfur dioxide < 37.0: Decision_Tree, 0.578
# total sulfur dioxide >= 37.0: Decision_Tree, 0.645
# total sulfur dioxide < 38.0: Decision_Tree, 0.573
# total sulfur dioxide >= 38.0: Decision_Tree, 0.643
# total sulfur dioxide < 39.0: Decision_Tree, 0.571
# total sulfur dioxide >= 39.0: Decision_Tree, 0.654
# total sulfur dioxide < 40.0: Decision_Tree, 0.579
# total sulfur dioxide >= 40.0: Decision_Tree, 0.635
# total sulfur dioxide < 41.0: Decision_Tree, 0.588
# total sulfur dioxide >= 41.0: Decision_Tree, 0.655
# total sulfur dioxide < 42.0: Decision_Tree, 0.558
# total sulfur dioxide >= 42.0: Decision_Tree, 0.632
# total sulfur dioxide < 43.0: Decision_Tree, 0.577
# total sulfur dioxide >= 43.0: Decision_Tree, 0.678
# total sulfur dioxide < 44.0: Decision_Tree, 0.556
# total sulfur dioxide >= 44.0: Decision_Tree, 0.656
# total sulfur dioxide < 45.0: Decision_Tree, 0.586
# total sulfur dioxide >= 45.0: Decision_Tree, 0.637
# total sulfur dioxide < 46.0: Decision_Tree, 0.576
# total sulfur dioxide >= 46.0: Decision_Tree, 0.667
# total sulfur dioxide < 47.0: Decision_Tree, 0.596
# total sulfur dioxide >= 47.0: Decision_Tree, 0.645
# total sulfur dioxide < 48.0: Decision_Tree, 0.574
# total sulfur dioxide >= 48.0: Decision_Tree, 0.652
# total sulfur dioxide < 49.0: Decision_Tree, 0.58
# total sulfur dioxide >= 49.0: Decision_Tree, 0.663
# total sulfur dioxide < 50.0: Decision_Tree, 0.599
# total sulfur dioxide >= 50.0: Decision_Tree, 0.674
# total sulfur dioxide < 51.0: Decision_Tree, 0.567
# total sulfur dioxide >= 51.0: Decision_Tree, 0.699
# total sulfur dioxide < 52.0: Decision_Tree, 0.574
# total sulfur dioxide >= 52.0: Naive_Bayes, 0.667
# total sulfur dioxide < 53.0: Decision_Tree, 0.581
# total sulfur dioxide >= 53.0: Decision_Tree, 0.689
# total sulfur dioxide < 54.0: Decision_Tree, 0.561
# total sulfur dioxide >= 54.0: Decision_Tree, 0.686
# total sulfur dioxide < 55.0: Decision_Tree, 0.572
# total sulfur dioxide >= 55.0: Decision_Tree, 0.692
# total sulfur dioxide < 56.0: Decision_Tree, 0.59
# total sulfur dioxide >= 56.0: Decision_Tree, 0.706
# total sulfur dioxide < 57.0: Decision_Tree, 0.571
# total sulfur dioxide >= 57.0: Decision_Tree, 0.683
# total sulfur dioxide < 58.0: Decision_Tree, 0.582
# total sulfur dioxide >= 58.0: Decision_Tree, 0.71
# total sulfur dioxide < 59.0: Decision_Tree, 0.558
# total sulfur dioxide >= 59.0: Decision_Tree, 0.742
# total sulfur dioxide < 60.0: Decision_Tree, 0.57
# total sulfur dioxide >= 60.0: Decision_Tree, 0.706
# total sulfur dioxide < 61.0: Decision_Tree, 0.562
# total sulfur dioxide >= 61.0: Decision_Tree, 0.695
# total sulfur dioxide < 62.0: Decision_Tree, 0.583
# total sulfur dioxide >= 62.0: Decision_Tree, 0.73
# total sulfur dioxide < 63.0: Decision_Tree, 0.572
# total sulfur dioxide >= 63.0: Decision_Tree, 0.731
# total sulfur dioxide < 64.0: Decision_Tree, 0.57
# total sulfur dioxide >= 64.0: Decision_Tree, 0.727
# total sulfur dioxide < 65.0: Decision_Tree, 0.584
# total sulfur dioxide >= 65.0: Decision_Tree, 0.733
# total sulfur dioxide < 66.0: Decision_Tree, 0.587
# total sulfur dioxide >= 66.0: Decision_Tree, 0.725
# total sulfur dioxide < 67.0: Decision_Tree, 0.574
# total sulfur dioxide >= 67.0: Decision_Tree, 0.701
# total sulfur dioxide < 68.0: Decision_Tree, 0.583
# total sulfur dioxide >= 68.0: Decision_Tree, 0.729
# total sulfur dioxide < 69.0: Decision_Tree, 0.575
# total sulfur dioxide >= 69.0: Decision_Tree, 0.715
# total sulfur dioxide < 70.0: Decision_Tree, 0.596
# total sulfur dioxide >= 70.0: Decision_Tree, 0.741
# total sulfur dioxide < 71.0: Decision_Tree, 0.57
# total sulfur dioxide >= 71.0: Decision_Tree, 0.719
# total sulfur dioxide < 72.0: Decision_Tree, 0.568
# total sulfur dioxide >= 72.0: Decision_Tree, 0.743
# total sulfur dioxide < 73.0: Decision_Tree, 0.588
# total sulfur dioxide >= 73.0: Decision_Tree, 0.728
# total sulfur dioxide < 74.0: Decision_Tree, 0.587
# total sulfur dioxide >= 74.0: Decision_Tree, 0.742
# total sulfur dioxide < 75.0: Decision_Tree, 0.584
# total sulfur dioxide >= 75.0: Decision_Tree, 0.758
# total sulfur dioxide < 76.0: Decision_Tree, 0.581
# total sulfur dioxide >= 76.0: Decision_Tree, 0.765
# total sulfur dioxide < 77.0: Decision_Tree, 0.584
# total sulfur dioxide >= 77.0: Naive_Bayes, 0.742
# total sulfur dioxide < 78.0: Decision_Tree, 0.576
# total sulfur dioxide >= 78.0: Decision_Tree, 0.775
# total sulfur dioxide < 79.0: Decision_Tree, 0.579
# total sulfur dioxide >= 79.0: Decision_Tree, 0.785
# total sulfur dioxide < 80.0: Decision_Tree, 0.565
# total sulfur dioxide >= 80.0: Decision_Tree, 0.755
# total sulfur dioxide < 81.0: Decision_Tree, 0.588
# total sulfur dioxide >= 81.0: Decision_Tree, 0.773
# total sulfur dioxide < 82.0: Decision_Tree, 0.577
# total sulfur dioxide >= 82.0: Naive_Bayes, 0.771
# total sulfur dioxide < 83.0: Decision_Tree, 0.591
# total sulfur dioxide >= 83.0: Naive_Bayes, 0.766
# total sulfur dioxide < 84.0: Decision_Tree, 0.58
# total sulfur dioxide >= 84.0: Naive_Bayes, 0.766
# total sulfur dioxide < 85.0: Decision_Tree, 0.578
# total sulfur dioxide >= 85.0: Naive_Bayes, 0.77
# total sulfur dioxide < 86.0: Decision_Tree, 0.59
# total sulfur dioxide >= 86.0: Decision_Tree, 0.775
# total sulfur dioxide < 87.0: Decision_Tree, 0.587
# total sulfur dioxide >= 87.0: Naive_Bayes, 0.799
# total sulfur dioxide < 88.0: Decision_Tree, 0.607
# total sulfur dioxide >= 88.0: Decision_Tree, 0.801
# total sulfur dioxide < 89.0: Decision_Tree, 0.578
# total sulfur dioxide >= 89.0: Naive_Bayes, 0.835
# total sulfur dioxide < 90.0: Decision_Tree, 0.582
# total sulfur dioxide >= 90.0: Decision_Tree, 0.809
# total sulfur dioxide < 91.0: Decision_Tree, 0.585
# total sulfur dioxide >= 91.0: Decision_Tree, 0.858
# total sulfur dioxide < 92.0: Decision_Tree, 0.573
# total sulfur dioxide >= 92.0: Decision_Tree, 0.863
# total sulfur dioxide < 93.0: Decision_Tree, 0.579
# total sulfur dioxide >= 93.0: Naive_Bayes, 0.859
# total sulfur dioxide < 94.0: Decision_Tree, 0.584
# total sulfur dioxide >= 94.0: Decision_Tree, 0.858
# total sulfur dioxide < 95.0: Decision_Tree, 0.581
# total sulfur dioxide >= 95.0: Naive_Bayes, 0.868
# total sulfur dioxide < 96.0: Decision_Tree, 0.586
# total sulfur dioxide >= 96.0: Decision_Tree, 0.867
# total sulfur dioxide < 97.0: Decision_Tree, 0.572
# total sulfur dioxide >= 97.0: Naive_Bayes, 0.886
# total sulfur dioxide < 98.0: Decision_Tree, 0.572
# total sulfur dioxide >= 98.0: Naive_Bayes, 0.886
# total sulfur dioxide < 99.0: Decision_Tree, 0.577
# total sulfur dioxide >= 99.0: Naive_Bayes, 0.906
# total sulfur dioxide < 100.0: Decision_Tree, 0.574
# total sulfur dioxide >= 100.0: Decision_Tree, 0.9
# total sulfur dioxide < 101.0: Decision_Tree, 0.584
# total sulfur dioxide >= 101.0: Decision_Tree, 0.884
# total sulfur dioxide < 102.0: Decision_Tree, 0.573
# total sulfur dioxide >= 102.0: Naive_Bayes, 0.905
# total sulfur dioxide < 103.0: Decision_Tree, 0.578
# total sulfur dioxide >= 103.0: Naive_Bayes, 0.891
# total sulfur dioxide < 104.0: Decision_Tree, 0.592
# total sulfur dioxide >= 104.0: Naive_Bayes, 0.918
# total sulfur dioxide < 105.0: Decision_Tree, 0.564
# total sulfur dioxide >= 105.0: Naive_Bayes, 0.914
# total sulfur dioxide < 106.0: Decision_Tree, 0.582
# total sulfur dioxide >= 106.0: Decision_Tree, 0.924
# total sulfur dioxide < 107.0: Decision_Tree, 0.588
# total sulfur dioxide >= 107.0: Naive_Bayes, 0.921
# total sulfur dioxide < 108.0: Decision_Tree, 0.578
# total sulfur dioxide >= 108.0: Decision_Tree, 0.921
# total sulfur dioxide < 109.0: Decision_Tree, 0.581
# total sulfur dioxide >= 109.0: Naive_Bayes, 0.933
# total sulfur dioxide < 110.0: Decision_Tree, 0.578
# total sulfur dioxide >= 110.0: Decision_Tree, 0.963
# total sulfur dioxide < 111.0: Decision_Tree, 0.587
# total sulfur dioxide >= 111.0: Decision_Tree, 0.967
# total sulfur dioxide < 112.0: Decision_Tree, 0.594
# total sulfur dioxide >= 112.0: Decision_Tree, 0.93
# total sulfur dioxide < 113.0: Decision_Tree, 0.581
# total sulfur dioxide >= 113.0: Decision_Tree, 0.92
# total sulfur dioxide < 114.0: Decision_Tree, 0.593
# total sulfur dioxide >= 114.0: Decision_Tree, 0.92
# total sulfur dioxide < 115.0: Decision_Tree, 0.586
# total sulfur dioxide >= 115.0: Decision_Tree, 0.955
# total sulfur dioxide < 116.0: Decision_Tree, 0.583
# total sulfur dioxide >= 116.0: Decision_Tree, 0.935
# total sulfur dioxide < 117.0: Decision_Tree, 0.581
# total sulfur dioxide >= 117.0: Decision_Tree, 0.91
# total sulfur dioxide < 118.0: Decision_Tree, 0.577
# total sulfur dioxide >= 118.0: Decision_Tree, 0.93
# total sulfur dioxide < 119.0: Decision_Tree, 0.577
# total sulfur dioxide >= 119.0: Decision_Tree, 0.95
# total sulfur dioxide < 120.0: Decision_Tree, 0.582
# total sulfur dioxide >= 120.0: Decision_Tree, 0.925
# total sulfur dioxide < 121.0: Decision_Tree, 0.588
# total sulfur dioxide >= 121.0: Decision_Tree, 0.95
# total sulfur dioxide < 122.0: Decision_Tree, 0.586
# total sulfur dioxide >= 122.0: Decision_Tree, 1.0
# total sulfur dioxide < 123.0: Decision_Tree, 0.579
# total sulfur dioxide >= 123.0: Decision_Tree, 0.967
# total sulfur dioxide < 124.0: Decision_Tree, 0.573
# total sulfur dioxide >= 124.0: Decision_Tree, 1.0
# total sulfur dioxide < 125.0: Decision_Tree, 0.594
# total sulfur dioxide >= 125.0: Decision_Tree, 0.942
# total sulfur dioxide < 126.0: Decision_Tree, 0.589
# total sulfur dioxide >= 126.0: Decision_Tree, 0.933
# total sulfur dioxide < 127.0: Decision_Tree, 0.585
# total sulfur dioxide >= 127.0: Decision_Tree, 0.933
# total sulfur dioxide < 128.0: Decision_Tree, 0.599
# total sulfur dioxide >= 128.0: Decision_Tree, 0.933
# total sulfur dioxide < 129.0: Decision_Tree, 0.576
# total sulfur dioxide >= 129.0: Decision_Tree, 0.967
# total sulfur dioxide < 130.0: Decision_Tree, 0.589
# total sulfur dioxide >= 130.0: Decision_Tree, 0.933
# total sulfur dioxide < 131.0: Decision_Tree, 0.59
# total sulfur dioxide >= 131.0: Decision_Tree, 0.917
# total sulfur dioxide < 132.0: Decision_Tree, 0.586
# total sulfur dioxide >= 132.0: Decision_Tree, 0.9
# total sulfur dioxide < 133.0: Decision_Tree, 0.586
# total sulfur dioxide >= 133.0: Decision_Tree, 0.85
# total sulfur dioxide < 134.0: Decision_Tree, 0.602
# total sulfur dioxide >= 134.0: Naive_Bayes, 0.917
# total sulfur dioxide < 135.0: Decision_Tree, 0.607
# total sulfur dioxide >= 135.0: Decision_Tree, 0.85
#
#
#
#
#
#
#
#
# alcohol < 9.4: Decision_Tree, 0.667
# alcohol >= 9.4: Decision_Tree, 0.58
# alcohol < 10.4: Decision_Tree, 0.661
# alcohol >= 10.4: Decision_Tree, 0.559
# alcohol < 11.4: Decision_Tree, 0.626
# alcohol >= 11.4: Decision_Tree, 0.578
# alcohol < 12.4: Decision_Tree, 0.6
# alcohol >= 12.4: Decision_Tree, 0.598
#
#
# Model (Left): total sulfur dioxide 16.0, Decision_Tree, 0.604, 0.1321084864391951
# Model (Right): total sulfur dioxide 16.0, Decision_Tree, 0.622, 0.8678915135608049
# Model (Phase 1): Decision_Tree, 0.581
#
# Best Model (Phase 2): total sulfur dioxide 16.0, Decision_Tree & Decision_Tree, 0.639

# %% [markdown]
# #### **Phase Three - Trial On Training Data**

# %%
def phaseThreeLeft(col, th, lmodel):
    lesserThan = df.loc[df[col] < th]
    lesserThan = np.array(lesserThan)
    x = lesserThan[:,:-1]
    y = lesserThan[:,-1]
    
    returnModelVal = 0
    
    if len(lesserThan) > 20:
        
        if lmodel == "Decision_Tree":
            DTclf = DecisionTreeClassifier()
            DTaccuracy = (cross_val_score(DTclf, x, y, cv=kf, scoring='accuracy')).mean()
            returnModelVal = DTaccuracy
                
        if lmodel == "Naive_Bayes":
            NBclf = GaussianNB()
            NBaccuracy = (cross_val_score(NBclf, x, y, cv=kf, scoring='accuracy')).mean()
            returnModelVal = NBaccuracy

        if lmodel == "K_Nearest_Neighbour":
            KNNclf = KNeighborsClassifier(n_neighbors=3)
            KNNaccuracy = (cross_val_score(KNNclf, x, y, cv=kf, scoring='accuracy')).mean()
            returnModelVal = KNNaccuracy

    LPercent = len(lesserThan)/len(data)
    
    return returnModelVal, LPercent

# %%
def phaseThreeRight(col, th, rmodel):
    greaterThan = df.loc[df[col] >= th]
    greaterThan = np.array(greaterThan)
    x = greaterThan[:,:-1]
    y = greaterThan[:,-1]
    
    returnModelVal = 0
    
    if len(greaterThan) > 20:
        
        if rmodel == "Decision_Tree":
            DTclf = DecisionTreeClassifier()
            DTaccuracy = (cross_val_score(DTclf, x, y, cv=kf, scoring='accuracy')).mean()
            returnModelVal = DTaccuracy
                
        if rmodel == "Naive_Bayes":
            NBclf = GaussianNB()
            NBaccuracy = (cross_val_score(NBclf, x, y, cv=kf, scoring='accuracy')).mean()
            returnModelVal = NBaccuracy

        if rmodel == "K_Nearest_Neighbour":
            KNNclf = KNeighborsClassifier(n_neighbors=3)
            KNNaccuracy = (cross_val_score(KNNclf, x, y, cv=kf, scoring='accuracy')).mean()
            returnModelVal = KNNaccuracy

    RPercent = len(greaterThan)/len(data)
    
    return returnModelVal, RPercent

# %%
lmodel = bestList[1][2][0]
rmodel = bestList[1][3][0]
col = bestList[1][4]
th = bestList[1][5]

print("Based on Phase Two")
print(f"Best Left ({col} < {th}): {round(phaseThreeLeft(col, th, lmodel)[0],3)}, {phaseThreeLeft(col, th, lmodel)[1]}")
print(f"Best Right ({col} >= {th}): {round(phaseThreeRight(col, th, rmodel)[0],3)}, {phaseThreeRight(col, th, lmodel)[1]}")

phaseThreeBest = (phaseThreeLeft(col, th, lmodel)[0] * phaseThreeLeft(col, th, lmodel)[1]) + (phaseThreeRight(col, th, lmodel)[0] * phaseThreeRight(col, th, lmodel)[1])
print(f"Overall Best ({col} {th}): {round(phaseThreeBest,3)}")
# Out:
# Based on Phase Two
# Best Left (total sulfur dioxide < 16.0): 0.583, 0.1321084864391951
# Best Right (total sulfur dioxide >= 16.0): 0.6, 0.8678915135608049
# Overall Best (total sulfur dioxide 16.0): 0.599

# %% [markdown]
# #### **Baseline Test Comparison**

# %%
DTclf = DecisionTreeClassifier()
baselineDT = (cross_val_score(DTclf, x, y, cv=kf, scoring='accuracy')).mean()

NBclf = GaussianNB()
baselineNB = (cross_val_score(NBclf, x, y, cv=kf, scoring='accuracy')).mean()

KNNclf = KNeighborsClassifier(n_neighbors=3)
baselineKNN = (cross_val_score(KNNclf, x, y, cv=kf, scoring='accuracy')).mean()

print(f"Proposed Approach: {round(phaseThreeBest,3)}\nBaseline DT: {round(baselineDT,3)}\nBaseline NB: {round(baselineNB,3)}\nBaseline KNN: {round(baselineKNN,3)}")
# Out:
# Proposed Approach: 0.599
# Baseline DT: 0.579
# Baseline NB: 0.549
# Baseline KNN: 0.497
